# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6         1360       150      11.9           1046      166
# 1        2.0         1292       112       9.4            955      103
# 2        2.2         1402        88       9.0            939      131
# 3        2.2         1376        80       9.2            948      172
# 4        1.6         1272        51       6.5            836      131
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1         1314      -200      13.5           1101      472
# 9353     2.4         1163      -200      11.4           1027      353
# 9354     2.4         1142      -200      12.4           1063      293
# 9355     2.1         1003      -200       9.5            961      235
# 9356     2.2         1071      -200      11.9           1047      265
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...

# %%
data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6         1360       150      11.9           1046      166
# 1     2.0         1292       112       9.4            955      103
# 2     2.2         1402        88       9.0            939      131
# 3     2.2         1376        80       9.2            948      172
# 4     1.6         1272        51       6.5            836      131
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0          1056      113          1692         1268  13.6  48.9  0.7578
# 1          1174       92          1559          972  13.3  47.7  0.7255
# 2          1140      114          1555         1074  11.9  54.0  0.7502
# 3          1092      122          1584         1203  11.0  60.0  0.7867
# 4          1205      116          1490         1110  11.2  59.6  0.7888

# %%
data.tail()
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9352     3.1         1314      -200      13.5           1101      472
# 9353     2.4         1163      -200      11.4           1027      353
# 9354     2.4         1142      -200      12.4           1063      293
# 9355     2.1         1003      -200       9.5            961      235
# 9356     2.2         1071      -200      11.9           1047      265
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 9352           539      190          1374         1729  21.9  29.3  0.7568
# 9353           604      179          1264         1269  24.3  23.7  0.7119
# 9354           603      175          1241         1092  26.9  18.3  0.6406
# 9355           702      156          1041          770  28.3  13.5  0.5139
# 9356           654      168          1129          816  28.5  13.1  0.5028

# %%
data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
train
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 4367     3.4         -200      -200    -200.0           -200     -200
# 794      1.2          964        68       3.7            692       88
# 8496     1.2          905      -200       2.9            648      188
# 3027     2.9         1084      -200      16.7           1200      185
# 8508     0.3          779      -200       0.2            402       34
# ...      ...          ...       ...       ...            ...      ...
# 5734  -200.0         1530      -200      24.8           1425      595
# 5191  -200.0          747      -200       1.5            543     -200
# 5390     3.6         1440      -200      24.3           1412      446
# 860      4.0         1418       542      19.5           1282      231
# 7270     3.8         1432      -200      16.5           1195      625
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T     RH        AH
# ...

# %%
test
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 2973     1.3          933      -200       6.4            831      105
# 3396  -200.0          894      -200       4.9            761       36
# 4372     2.6         1226      -200      14.6           1138      307
# 6025     3.1         1101      -200      14.5           1134      427
# 7960     1.3          966      -200       4.9            760      302
# ...      ...          ...       ...       ...            ...      ...
# 724      2.4         -200       160    -200.0           -200      175
# 4407     3.0         1227      -200      17.8           1233      519
# 3772     1.0          935      -200       5.2            774       43
# 9069     2.4         1175      -200      11.7           1040      362
# 5360  -200.0         1118      -200       9.3            951     -200
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T     RH        AH
# ...

# %%
corr_matrix = data.corr()

# %%
corr_matrix['AH'].sort_values(ascending=False)
# Out:
# AH               1.000000
# C6H6(GT)         0.984555
# T                0.981001
# RH               0.943995
# PT08.S1(CO)      0.764903
# PT08.S4(NO2)     0.691913
# PT08.S2(NMHC)    0.646572
# PT08.S3(NOx)     0.621618
# PT08.S5(O3)      0.519467
# NMHC(GT)         0.012500
# CO(GT)          -0.045892
# NO2(GT)         -0.060440
# NOx(GT)         -0.095847
# Name: AH, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ["C6H6(GT)","AH", "NOx(GT)"]
scatter_matrix(data[attributes], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='C6H6(GT)', ylabel='C6H6(GT)'>,
#         <AxesSubplot:xlabel='AH', ylabel='C6H6(GT)'>,
#         <AxesSubplot:xlabel='NOx(GT)', ylabel='C6H6(GT)'>],
#        [<AxesSubplot:xlabel='C6H6(GT)', ylabel='AH'>,
#         <AxesSubplot:xlabel='AH', ylabel='AH'>,
#         <AxesSubplot:xlabel='NOx(GT)', ylabel='AH'>],
#        [<AxesSubplot:xlabel='C6H6(GT)', ylabel='NOx(GT)'>,
#         <AxesSubplot:xlabel='AH', ylabel='NOx(GT)'>,
#         <AxesSubplot:xlabel='NOx(GT)', ylabel='NOx(GT)'>]], dtype=object)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')
imputer.fit(data)
# Out:
# SimpleImputer(strategy='median')

# %%
x = imputer.transform(data)

# %%
data_tr = pd.DataFrame(x, columns=data.columns)

# %%
data_tr.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1     2.0       1292.0     112.0       9.4          955.0    103.0
# 2     2.2       1402.0      88.0       9.0          939.0    131.0
# 3     2.2       1376.0      80.0       9.2          948.0    172.0
# 4     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888

# %%
data_tr.tail()
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9352     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 9353     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 9354     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 9355     2.1       1003.0    -200.0       9.5          961.0    235.0
# 9356     2.2       1071.0    -200.0      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 9352         539.0    190.0        1374.0       1729.0  21.9  29.3  0.7568
# 9353         604.0    179.0        1264.0       1269.0  24.3  23.7  0.7119
# 9354         603.0    175.0        1241.0       1092.0  26.9  18.3  0.6406
# 9355         702.0    156.0        1041.0        770.0  28.3  13.5  0.5139
# 9356         654.0    168.0        1129.0        816.0  28.5  13.1  0.5028

# %%
data_tr.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('std_scaler', StandardScaler())
])

# %%
my_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('std_scaler', StandardScaler())])

# %%
data_num_tr = my_pipeline.fit_transform(data)

# %%
data_num_tr
# Out:
# array([[ 0.4739999 ,  0.94298276,  2.21123554, ...,  0.08846247,
#          0.18383116,  0.19488093],
#        [ 0.46627322,  0.73680662,  1.93938293, ...,  0.08151824,
#          0.16039979,  0.19405218],
#        [ 0.46884878,  1.07032685,  1.76768654, ...,  0.04911182,
#          0.28341445,  0.19468593],
#        ...,
#        [ 0.47142434,  0.28200632, -0.29267014, ...,  0.39632347,
#         -0.41366862,  0.19187384],
#        [ 0.467561  , -0.13944196, -0.29267014, ...,  0.4287299 ,
#         -0.50739408,  0.188623  ],
#        [ 0.46884878,  0.06673418, -0.29267014, ...,  0.43335938,
#         -0.51520453,  0.1883382 ]])

# %%
from sklearn.linear_model import LinearRegression
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
model = LinearRegression()
# model = DecisionTreeRegressor()
# model = RandomForestRegressor()
data_labels = data['AH'].copy
data_labels = data.drop('AH', axis=1)
model.fit(data_num_tr, data_labels)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
data_predictions = model.predict(data_num_tr)
mse = mean_squared_error(data_labels, data_predictions)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 1.4060162456505278e-12

# %%
mse
# Out:
# 1.9768816830332052e-24

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, data_num_tr, data_labels, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.31607547e-12, 2.01513161e-12, 3.12118591e-12, 2.74351057e-12,
#        2.74200580e-12, 2.33011693e-12, 2.93756348e-12, 3.63247791e-12,
#        2.70469787e-12, 2.35105470e-12])

# %%
def print_scores(scores):
    print("Scores", scores)
    print("Mean", scores.mean())
    print("Standard Deviation", scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores [2.31607547e-12 2.01513161e-12 3.12118591e-12 2.74351057e-12
#  2.74200580e-12 2.33011693e-12 2.93756348e-12 3.63247791e-12
#  2.70469787e-12 2.35105470e-12]
# Mean 2.689382023998644e-12
# Standard Deviation 4.4507531936858593e-13

# %% [markdown]
# ## Linear Regression:
#
#     Scores [2.31607547e-12 2.01513161e-12 3.12118591e-12 2.74351057e-12
#      2.74200580e-12 2.33011693e-12 2.93756348e-12 3.63247791e-12
#      2.70469787e-12 2.35105470e-12]
#     Mean 2.689382023998644e-12
#     Standard Deviation 4.4507531936858593e-13
#
# ## Decision Tree Regressor:
#     Scores [77.51742359 58.37553924 49.02276592 52.97638274 49.65137183 57.64812189
#      73.70775342 57.51200688 53.49193914 49.40399098]
#     Mean 57.93072956383967
#     Standard Deviation 9.475544209414174
#
# ## RandomForest Regression:
#     Scores [59.59293827 32.20742733 31.81957946 36.24702342 29.23888252 33.17693254
#      47.21545798 40.09888383 29.40434099 31.58719516]
#     Mean 37.05886614995788
#     Standard Deviation 9.146478201714395

# %%
x_test = data.drop("AH", axis=1)
y_test = data['AH'].copy()
x_test_prepared = my_pipeline.transform(x_test)
final_prediction = model.predict(x_test_prepared)
final_mse = mean_squared_error(y_test, final_prediction)
final_rmse = np.sqrt(final_mse)
print(final_prediction, list(y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-40a677aa127e> in <module>
#       1 x_test = data.drop("AH", axis=1)
#       2 y_test = data['AH'].copy()
# ----> 3 x_test_prepared = my_pipeline.transform(x_test)
#       4 final_prediction = model.predict(x_test_prepared)
#       5 final_mse = mean_squared_error(y_test, final_prediction)
#
# c:\users\omprakash\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\pipeline.py in _transform(self, X)
#     547         Xt = X
#     548         for _, _, transform in self._iter():
# --> 549             Xt = transform.transform(Xt)
#     550         return Xt
#     551
#
# c:\users\omprakash\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\impute\_base.py in transform(self, X)
#     413         check_is_fitted(self)
#     414
# ...
